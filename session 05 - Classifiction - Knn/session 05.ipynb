# %%
# method 2 = modeling with making modular n_feature col 
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier  #Knn modeling




df=pd.read_csv("your data file ",header=None)
df.columns=['all features in .data file ','.....']


# we we have categorical or string type of data "df.info()"
# we make a col and coverts  similar values to a index of a list that 
#they become a numerical num
#we must do this for all features ... 


buying_lst=list(df['buying'].unique())
df['n_buying'] = [buying_lst.index(i) for i in df['buying']
#...

                  
# then we get this  numerical col                  
df=df[['n_buying' , '.....' ]]


# pxy train test 
predict='a feature'
X=df.drop(predict)
Y=df[predict]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1)


#modeling mfs
model=KNeighborsClassifier(n_neighbors=5)  # knn modeling and its knn deep used and must be odd
model=model.fit(x_train,y_train)
score=model.score(x_test,y_test)
print(score)




# Testing accuracy according to upon score 
# from sklearn.metrics import accuracy_score
# predictions = model.predict(x_test)
# accuracy_score(predictions,y_test)




# saving model
# import joblib
# file_name='knn.sav'
# joblib.dump(model,file_name)

# %%
#  method 2 = modeling with making manualy n_feature col with no model
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier  #Knn modeling
from sklearn.preprocessing import LabelEncoder



df=pd.read_csv("your data file ",header=None)
df.columns=['all features in .data file ','.....']


# we we have categorical or string type of data "df.info()"
# we make a col and coverts  similar values to a index of a list that 
#they become a numerical num
#this way is modular and easy

encoder=LabelEncoder()


buying=encoder.fit_transform(df['buying'])
#... we do this for all features


# xy train test 
X=list(zip(buying,)) 
Y=predictfeature
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1)# you can use random_state=123 to freeze random value




#modeling mfs
for i in range(3,5,7): # for getting better score i used a for but you can delete the for and use odd num in n_neighbors
    model=KNeighborsClassifier(n_neighbors=i) # knn modeling and its knn deep used and must be odd
    model.fit(x_train,y_train)
    score=model.score(x_test,y_test)
    print(score)






# Testing accuracy according to upon score 
# from sklearn.metrics import accuracy_score
# predictions = model.predict(x_test)
# accuracy_score(predictions,y_test)





# saving model
# import joblib
# file_name='knn.sav'
# joblib.dump(model,file_name)
