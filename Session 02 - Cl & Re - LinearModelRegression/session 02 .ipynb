# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
# sklearn tools to Train and Test 
from sklearn.model_selection import train_test_split
from sklearn import linear_model


df = pd.read_csv("winequality-red.csv", sep=";")

# %%
# df = df.astype(int)

# %%
df= df[['alcohol','fixed acidity','sulphates','quality']]

# %%
predict = "quality"
X = np.array(df.drop([predict], axis=1))
Y = np.array(df[predict])
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)


model = linear_model.LinearRegression()
model.fit(x_train,y_train)
score=model.score(x_test,y_test)

# show acc
print(score)
# Out:
# 0.3795635181914019

# %%
predictions = model.predict(x_test)
plt.figure(figsize=(15,5))
plt.plot(predictions,label="predictions")
plt.plot(y_test,label="Real " )
plt.legend()
plt.grid()
plt.show()

# %%
predictions = model.predict(x_test)
for i in range(len(predictions)):
    print(f"predictions = {predictions[i]}  ,  Real = {y_test[i]}")
# Out:
# predictions = 5.77948571266351  ,  Real = 7
# predictions = 5.304693886666148  ,  Real = 5
# predictions = 5.095437424216251  ,  Real = 6
# predictions = 6.2681792294089735  ,  Real = 7
# predictions = 5.315929663747182  ,  Real = 5
# predictions = 5.2510337728037575  ,  Real = 6
# predictions = 6.196531439083824  ,  Real = 6
# predictions = 5.904354184140662  ,  Real = 6
# predictions = 5.101712665800511  ,  Real = 6
# predictions = 5.151141410047985  ,  Real = 5
# predictions = 5.48145667363898  ,  Real = 6
# predictions = 5.2008581292429  ,  Real = 6
# predictions = 5.307746032749028  ,  Real = 5
# predictions = 5.212526230542588  ,  Real = 5
# predictions = 6.675626292017182  ,  Real = 7
# predictions = 5.3746857956617955  ,  Real = 5
# predictions = 6.220570207417768  ,  Real = 6
# predictions = 5.948568126582942  ,  Real = 6
# predictions = 6.357709330236782  ,  Real = 7
# predictions = 5.479386201522349  ,  Real = 5
# predictions = 5.417217256627283  ,  Real = 5
# predictions = 5.87137426055539  ,  Real = 6
# predictions = 5.752042998064875  ,  Real = 6
# predictions = 5.879549024837781  ,  Real = 7
# predictions = 5.22796677709125  ,  Real = 5
# predictions = 5.268959382256179  ,  Real = 6
# predictions = 5.020493846439592  ,  Real = 5
# predictions = 5.664954661191062  ,  Real = 4
# predictions = 5.880575755977824  ,  Real = 5
# predictions = 5.679045034789189  ,  Real = 6
# predictions = 5.353149823663135  ,  Real = 5
# predictions = 5.226625470856478  ,  Real = 6
# predictions = 5.67834246905462  ,  Real = 6
# predictions = 5.303612920602481  ,  Real = 5
# predictions = 5.105737619133878  ,  Real = 5
# predictions = 6.267629879661378  ,  Real = 7
# predictions = 5.21990017162204  ,  Real = 5
# predictions = 5.302812097399541  ,  Real = 5
# predictions = 6.226699341506788  ,  Real = 7
# predictions = 5.755681718982431  ,  Real = 5
# predictions = 5.187046863876453  ,  Real = 6
# predictions = 5.407331652496785  ,  Real = 6
# predictions = 5.0724608538854  ,  Real = 5
# predictions = 5.652384686366988  ,  Real = 5
# predictions = 5.104576129033367  ,  Real = 5
# predictions = 6.259734223610666  ,  Real = 7
# predictions = 6.495640409542972  ,  Real = 7
# predictions = 5.108519523700841  ,  Real = 6
# predictions = 6.255764228795903  ,  Real = 7
# predictions = 5.939564904321275  ,  Real = 5
# predictions = 6.151396855056585  ,  Real = 6
# predictions = 5.322817045684356  ,  Real = 5
# predictions = 6.0082793323165165  ,  Real = 7
# predictions = 5.759337138702463  ,  Real = 7
# predictions = 5.566447938248874  ,  Real = 5
# predictions = 5.336988977948376  ,  Real = 5
# predictions = 5.139482175464059  ,  Real = 5
# predictions = 5.631957004174263  ,  Real = 5
# predictions = 6.1732757605212925  ,  Real = 6
# predictions = 5.832669168728434  ,  Real = 6
# predictions = 5.8915324248271785  ,  Real = 5
# predictions = 6.558663377935551  ,  Real = 7
# predictions = 5.423420840890461  ,  Real = 7
# predictions = 5.354302447047883  ,  Real = 5
# predictions = 5.607728518361244  ,  Real = 6
# predictions = 5.605918386415719  ,  Real = 5
# predictions = 4.989531194676373  ,  Real = 6
# predictions = 5.940277371400656  ,  Real = 6
# predictions = 5.325886925198762  ,  Real = 6
# predictions = 5.363485485443812  ,  Real = 6
# predictions = 5.2143991530934315  ,  Real = 5
# predictions = 5.274361108687369  ,  Real = 5
# predictions = 5.2308302403241065  ,  Real = 5
# predictions = 6.283854550610503  ,  Real = 7
# predictions = 5.350800243314824  ,  Real = 5
# predictions = 5.105305294915225  ,  Real = 5
# predictions = 5.61220352934479  ,  Real = 5
# predictions = 5.121889598132873  ,  Real = 5
# predictions = 5.792667104245517  ,  Real = 6
# predictions = 5.864369853089272  ,  Real = 6
# predictions = 6.376481131100005  ,  Real = 7
# predictions = 5.501498123415894  ,  Real = 5
# predictions = 5.423312682077282  ,  Real = 5
# predictions = 6.035396846880629  ,  Real = 6
# predictions = 5.277224571920226  ,  Real = 6
# predictions = 5.8256736279780785  ,  Real = 4
# predictions = 6.106803788690229  ,  Real = 7
# predictions = 5.709205828720419  ,  Real = 5
# predictions = 5.310690020018728  ,  Real = 6
# predictions = 5.644192188653072  ,  Real = 6
# predictions = 5.274001476418847  ,  Real = 6
# predictions = 6.206559634261505  ,  Real = 7
# predictions = 6.2681792294089735  ,  Real = 7
# predictions = 5.979388187298977  ,  Real = 6
# predictions = 5.212526230542588  ,  Real = 5
# predictions = 5.410294407827059  ,  Real = 5
# predictions = 6.085753341204797  ,  Real = 6
# predictions = 5.537277684999657  ,  Real = 5
# predictions = 5.144866168463725  ,  Real = 5
# predictions = 5.0708315727031845  ,  Real = 5
# predictions = 5.739978763004564  ,  Real = 5
# predictions = 6.2681792294089735  ,  Real = 7
# predictions = 6.385196378414229  ,  Real = 7
# predictions = 5.99699746343264  ,  Real = 7
# predictions = 6.497000483838319  ,  Real = 7
# predictions = 5.569041159965813  ,  Real = 5
# predictions = 6.002372589716543  ,  Real = 6
# predictions = 5.51007861176965  ,  Real = 6
# predictions = 5.1211692989667785  ,  Real = 5
# predictions = 5.169463153261029  ,  Real = 5
# predictions = 6.111476349239561  ,  Real = 6
# predictions = 6.692237195382119  ,  Real = 6
# predictions = 5.9161471430560075  ,  Real = 6
# predictions = 5.05047482423656  ,  Real = 5
# predictions = 5.1815547120636065  ,  Real = 4
# predictions = 6.49781017375702  ,  Real = 7
# predictions = 5.763081225580122  ,  Real = 6
# predictions = 5.97511072588122  ,  Real = 6
# predictions = 6.094179578942532  ,  Real = 7
# predictions = 5.2765042727541305  ,  Real = 6
# predictions = 5.3981212903585885  ,  Real = 5
# predictions = 5.844184054041147  ,  Real = 6
# predictions = 5.899978465254535  ,  Real = 6
# predictions = 5.053959294538094  ,  Real = 5
# predictions = 5.285381602771092  ,  Real = 5
# predictions = 5.19941753091071  ,  Real = 5
# predictions = 5.3201432999305736  ,  Real = 5
# predictions = 5.773992837255683  ,  Real = 6
# predictions = 5.053959294538094  ,  Real = 5
# predictions = 5.307916982167527  ,  Real = 5
# predictions = 5.517235511627762  ,  Real = 4
# predictions = 6.211349943934761  ,  Real = 5
# predictions = 6.023171563746632  ,  Real = 6
# predictions = 5.274451534069025  ,  Real = 6
# predictions = 5.708124862656752  ,  Real = 5
# predictions = 5.933812412337324  ,  Real = 6
# predictions = 6.499233038657685  ,  Real = 6
# predictions = 5.20643080509259  ,  Real = 6
# predictions = 5.432541812276051  ,  Real = 5
# predictions = 5.777766006099639  ,  Real = 7
# predictions = 5.5886591522398374  ,  Real = 5
# predictions = 6.254610570782106  ,  Real = 7
# predictions = 6.05293550032226  ,  Real = 6
# predictions = 5.565179323964232  ,  Real = 5
# predictions = 5.078826520851314  ,  Real = 6
# predictions = 6.231823717930328  ,  Real = 7
# predictions = 5.631957004174263  ,  Real = 5
# predictions = 5.225887438258858  ,  Real = 6
# predictions = 5.76146081111367  ,  Real = 7
# predictions = 5.366240789863487  ,  Real = 5
# predictions = 5.271579204120406  ,  Real = 5
# predictions = 5.333764847817948  ,  Real = 6
# predictions = 6.244023435546086  ,  Real = 7
# predictions = 5.38876730254416  ,  Real = 6
# predictions = 5.745273365251624  ,  Real = 5
# predictions = 5.095257608081989  ,  Real = 5
# predictions = 5.524160118652016  ,  Real = 6
# predictions = 6.248605570713763  ,  Real = 7
# predictions = 5.073892585501827  ,  Real = 6
# predictions = 5.897663317140227  ,  Real = 6
